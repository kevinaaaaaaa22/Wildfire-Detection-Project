# %%
import numpy as np

x = np.zeros((1060, 6, 340, 444))
with open("C:\\Users\\yangz\\Desktop\\FireProjectBatchDownloadNew\\Detection\\Detection1060-2120RescaledFiltered.npy", 'rb') as f1:
        x = np.load(f1)

# %%
xNew = np.zeros((636, 6, 340, 444))

# %%
for i in range (636):
    xNew[i] = x[i]

# %%
import matplotlib.pyplot as plt

img = xNew[635]
img = np.reshape(img, (6, 340, 444))

fig = plt.figure(figsize=(15,15))
plt.imshow(img[5], cmap="Oranges")
#plt.clim(-500, 650)
#plt.clim(-1500, 1950)
plt.title("img")
plt.colorbar()
plt.show()

# %%
path = "C:\\Users\\yangz\\Desktop\\FireProjectBatchDownloadNew\\DetectionDatasetFinal\\TrainingB_1000-1696"
np.save(path, xNew)

# %%
xNew2 = np.zeros((212, 905760))
for i in range (696, 908):
    xNew2[i-696] = x[i]

# %%
import matplotlib.pyplot as plt

img = xNew2[211]
img = np.reshape(img, (6, 340, 444))

fig = plt.figure(figsize=(15,15))
plt.imshow(img[5], cmap="Oranges")
#plt.clim(-500, 650)
#plt.clim(-1500, 1950)
plt.title("img")
plt.colorbar()
plt.show()

# %%
path = "C:\\Users\\yangz\\Desktop\\FireProjectBatchDownloadNew\\DetectionDatasetFinalFlattened\\Testing_1696-1908"
np.save(path, xNew2)

# %%
xNew3 = np.zeros((212, 905760))
for i in range (908, 1120):
    xNew3[i-908] = x[i]

# %%
import matplotlib.pyplot as plt

img = xNew3[211]
img = np.reshape(img, (6, 340, 444))

fig = plt.figure(figsize=(15,15))
plt.imshow(img[5], cmap="Oranges")
#plt.clim(-500, 650)
#plt.clim(-1500, 1950)
plt.title("img")
plt.colorbar()
plt.show()

# %%
path = "C:\\Users\\yangz\\Desktop\\FireProjectBatchDownloadNew\\DetectionDatasetFinalFlattened\\Validation_1908-2120"
np.save(path, xNew3)
